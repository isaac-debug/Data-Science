# %% [markdown]
# <a href="https://colab.research.google.com/github/isaac-debug/Data-Science/blob/main/house_price_crawler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
total_data = []
taipei_data = []
yilan_data = []
# 106-1 ~ 110-11

# %% [markdown]
# # Crawling Data

# %% [markdown]
# ## 台北市

# %%
# 士林 7,298 
res = requests.get('https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/5cc16da7b16e4696273314714f290855?q=...')
print(res)
print(len(res.json()))
taipei_1 = res.json()
taipei_data = taipei_1
total_data = total_data + taipei_1
print('total = ', len(total_data))
#data = pd.DataFrame.from_records(res.json())
# Out:
# <Response [200]>
# 7298
# total =  7298

# %%
# 大同 4,602 
res = requests.get('https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/f4872e614661fdc650450706dc9b6344?q=...')
print(res)
print(len(res.json()))
taipei_2 = res.json()
taipei_data = taipei_data + taipei_2
total_data = total_data + taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 4610
# total =  11908

# %%
# 中山 106-1 107-12  5,027
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/46ebb8381e90cf96a95d7d47d3a10575?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
taipei_3 = res.json()
taipei_data = taipei_data + taipei_3
total_data = total_data + taipei_3
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 5027
# total =  16935

# %%
# 中山 108-1 110-11  8,517
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/99ab47493709f1102dfff44f7d3dfaf8?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
taipei_4 = res.json()
taipei_data = taipei_data + taipei_4
total_data = total_data + taipei_4
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 8517
# total =  25452

# %%
# 中正  5,713
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/7e1d204eb10171d1c4ec7355b6a89f97?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
taipei_daan = res.json()
taipei_data = taipei_data + taipei_daan
total_data = total_data + taipei_daan
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 5713
# total =  31165

# %%
# 松山 6428
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/577b0258c338725ed317c2e62060add2?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
taipei_daan = res.json()
taipei_data = taipei_data + taipei_daan
total_data = total_data + taipei_daan
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 6428
# total =  37593

# %%
# 信義 6823
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/2c63d6e4abc9d4cc2d31e9e4cb4a8485?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
taipei_daan = res.json()
taipei_data = taipei_data + taipei_daan
total_data = total_data + taipei_daan
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 6835
# total =  44428

# %%
# 南港  4,016 
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/f14ff4341677649d530c09c8370def55?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
taipei_daan = res.json()
taipei_data = taipei_data + taipei_daan
total_data = total_data + taipei_daan
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 4051
# total =  48479

# %%
# 萬華 6,920 
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/ade4de703b4452a0905872fccb31e6f4?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
taipei_daan = res.json()
taipei_data = taipei_data + taipei_daan
total_data = total_data + taipei_daan
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 6962
# total =  55441

# %%
# 大安 8763
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/70cb5792758e88317890f25f1e1c96c7?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
taipei_daan = res.json()
taipei_data = taipei_data + taipei_daan
total_data = total_data + taipei_daan
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 8839
# total =  64280

# %%
# 內湖 12,164
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/25bb18d592473dac056d0e97ee51f3ba?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
taipei_daan = res.json()
taipei_data = taipei_data + taipei_daan
total_data = total_data + taipei_daan
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 10249
# total =  74529

# %%
# 北投 9,109
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/fca2bf3ca5f863581ddba164b7334f69?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
taipei_daan = res.json()
taipei_data = taipei_data + taipei_daan
total_data = total_data + taipei_daan
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 9142
# total =  83671

# %%
# 文山 9,240
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/ea4da51924d78b699251790a0efb669a?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
taipei_daan = res.json()
taipei_data = taipei_data + taipei_daan
total_data = total_data + taipei_daan
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 9281
# total =  92952

# %% [markdown]
# ## 新北市

# %%
# 八里 2,812
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/0e448b4681b5dfa775c723bd44907ffc?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_1 = res.json()
new_taipei_data = new_taipei_1
total_data = total_data + new_taipei_1
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 2840
# total =  95792

# %%
# 三芝 1,574 
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/2c80847195da5c2846cd6170a4c9b27a?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 1590
# total =  97382

# %%
# 三重 up  5,911
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/2cbc77cfd6de2568df534fecb80b236e?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 5911
# total =  103293

# %%
# 三重 down  9,575 
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/42a07a957c10754dd8ba362d26e874e0?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 9710
# total =  113003

# %%
# 三峽 6,793
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/9f13bab133bced1c976470f37840c79c?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 6827
# total =  119830

# %%
# 土城 up  4,309 
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/8779ff699b1cf0d41696ef97f141d886?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 4309
# total =  124139

# %%
# 土城 down 6,948 
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/85a660adbdbe222461065cb2961f19c7?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 6948
# total =  131087

# %%
# 中和 part1(106-1 ~107-12) 8,015
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/d6b7f4cbe2be9176a27fbe7657ea43da?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 8021
# total =  139108

# %%
# 中和 part2(108-1 ~110-11) 12,226
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/2e2010b1b6bb9202527d7637ba9d5d79?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 8123
# total =  147231

# %%
# 五股  7,262 
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/6a891abed1d5d46b78bc66a05160550c?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 7296
# total =  154527

# %%
# 平溪 3
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/d4e5d721eea8cf2d2350faf5d9e2445e?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 3
# total =  154530

# %%
# 永和  8,546
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/ea9db993c8b80ba668825902d62fbe8c?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 8596
# total =  163126

# %%
# 石門 34
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/5d9578f3029d596340da2cdd8a4ceda2?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 34
# total =  163160

# %%
# 石碇 37
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/20aa8b0f715a6344ce7385a59a4e8df4?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 37
# total =  163197

# %%
# 汐止 part1 106-1 107-12  6,384
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/20aa8b0f715a6344ce7385a59a4e8df4?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 37
# total =  163234

# %%
# 汐止 part2 108-1 110-11 10,170 
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/6a54751c06cdadbd5f5c6ce8075ea6d1?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 10332
# total =  173566

# %%
# 玶林 4
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/16858e41bc86a13c5d622375d97afce3?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 4
# total =  173570

# %%
# 林口 up 5,230
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/a9d0510e10039ea6fb12f86060e4bf40?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 5230
# total =  178800

# %%
# 林口 down 8567
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/102e44e35a89ccbcc2e813ae2a9b7e15?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 8567
# total =  187367

# %%
# 板橋 up 10,349
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/f45d87a4ed292e759a6345aef3703403?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 10349
# total =  197716

# %%
# 板橋 middle 108-1 108-12 4,680
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/e9bd74efb7c847de38a3c855c3709c9b?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 4680
# total =  202396

# %%
# 板橋 down 109-1 110-11  7,855
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/dfb9555ae1423b48a8f40d22fa37587c?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 7855
# total =  210251

# %%
# 金山 674 
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/ae047f63ef7c55e88af1570f551ed96e?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 678
# total =  210929

# %%
# 泰山 3,159
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/43edf53b641c9f8cc606f0ef951e3ba3?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 3190
# total =  214119

# %%
# 烏來 4
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/22b76489533511e2071bb198d2caeb71?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 4
# total =  214123

# %%
# 貢寮 83
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/c6129ed9124447b72c8af1f3461bfa28?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 83
# total =  214206

# %%
# 淡水 uo  8,739 
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/d0dfc04d75ec206e37bc83368bbeabb2?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 8739
# total =  222945

# %%
# 淡水 middle 108-1 108-12 4083
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/9647ec38ab642ffb4a7d40d3c0ff678e?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 4083
# total =  227028

# %%
# 淡水 down 9,038
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/49e6d034dc2f0fc642c893ad663312f4?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 9038
# total =  236066

# %%
# 深坑 1,074 
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/18d8d727f32cf5fd562b931409dddd58?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 1087
# total =  237153

# %%
# 新店 up 7,212
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/b9b2524ec764aa918bb4cf1b01f55ac9?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 7212
# total =  244365

# %%
# 新店 down　10,061
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/db4c324126d449c2c96173688067d85f?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 10061
# total =  254426

# %%
# 新莊 up 8,269
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/55ca52eb80bd5b4771e727a4b97d9995?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 8269
# total =  262695

# %%
# 新莊 middle 5,215
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/d803feb12482e7011705d4a648a4a561?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 5215
# total =  267910

# %%
# 新莊down  9,520 
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/a9f90c7f0eee406a19d2eb1f231a131e?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 9520
# total =  277430

# %%
# 瑞芳 875 
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/f2fd927d40cb3f27ed5f1a6f5ad5ab99?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 884
# total =  278314

# %%
# 萬里 648 
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/0d25069e1a99968b5b27c2033bb12737?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 652
# total =  278966

# %%
# 樹林  6,945 
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/2fc33297df38cfca118b1e241e3dbea7?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 7009
# total =  285975

# %%
# 雙溪 59
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/4a47185c12c86d633d1f31ddea025ecf?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 59
# total =  286034

# %%
# 蘆洲 7,442 
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/2fc33297df38cfca118b1e241e3dbea7?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 7009
# total =  293043

# %%
# 鶯歌 6,577 
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/e4eceda73589fd756cfb8462f202d70a?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
new_taipei_2 = res.json()
new_taipei_data = new_taipei_data + new_taipei_2
total_data = total_data + new_taipei_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 6577
# total =  306629

# %% [markdown]
# ## 宜蘭

# %%
# 三星 918
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/cf0b0238c393daa027feb4cb749013e7?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
ilan_1 = res.json()
ilan_data = ilan_1
total_data = total_data + ilan_1
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 928
# total =  307557

# %%
# 大同 7
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/bbd81fdd4dd2dfec5c178f604751cad7?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
ilan_2 = res.json()
ilan_data = ilan_data + ilan_2
total_data = total_data + ilan_2
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 7
# total =  307564

# %%
# 五結 2,538
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/e495e2bfa1193defc11f3add08770ee8?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
ilan_3 = res.json()
ilan_data = ilan_data + ilan_3
total_data = total_data + ilan_3
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 2557
# total =  310121

# %%
# 冬山 2,489
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/4e4af353f90d80b7de28f122637936b4?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
ilan_4 = res.json()
ilan_data = ilan_data + ilan_4
total_data = total_data + ilan_4
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 2507
# total =  312628

# %%
# 壯圍 5,477
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/671565bce15d633e58141699647d2e4b?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
ilan_5 = res.json()
ilan_data = ilan_data + ilan_5
total_data = total_data + ilan_5
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 1082
# total =  313710

# %%
# 宜蘭市
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/a3633b24b65c822934b616255be8fd56?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
ilan_6 = res.json()
ilan_data = ilan_data + ilan_6
total_data = total_data + ilan_6
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 5520
# total =  319230

# %%
# 南澳 5
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/5936c33863b25c7f28a5b231f2f0c2ba?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
ilan_7 = res.json()
ilan_data = ilan_data + ilan_7
total_data = total_data + ilan_7
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 5
# total =  319235

# %%
# 員山 1162
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/0a9a9698a2d24aadb0496ea3ff78b247?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
ilan_8 = res.json()
ilan_data = ilan_data + ilan_8
total_data = total_data + ilan_8
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 1171
# total =  320406

# %%
# 頭城 1154
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/6202f4c62a7b567a92e6295871a4791d?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
ilan_9 = res.json()
ilan_data = ilan_data + ilan_9
total_data = total_data + ilan_9
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 1174
# total =  321580

# %%
# 礁溪 2,903
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/96076a77e018caad3168d44149dfcf00?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
ilan_10 = res.json()
ilan_data = ilan_data + ilan_10
total_data = total_data + ilan_10
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 2959
# total =  324539

# %%
# 礁溪 2,903
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/96076a77e018caad3168d44149dfcf00?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
ilan_11 = res.json()
ilan_data = ilan_data + ilan_11
total_data = total_data + ilan_11
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 2959
# total =  327498

# %%
# 羅東 3,255 
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/8b788cb2114ec93b3434a2601fd57bd1?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
ilan_12 = res.json()
ilan_data = ilan_data + ilan_12
total_data = total_data + ilan_12
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 3290
# total =  330788

# %%
# 蘇澳 1,424
url = 'https://lvr.land.moi.gov.tw/SERVICE/QueryPrice/544d38e36aef2d4d6ed2e72a5fa668d0?q=...'
res = requests.get(url)
print(res)
print(len(res.json()))
ilan_13 = res.json()
ilan_data = ilan_data + ilan_13
total_data = total_data + ilan_13
print('total = ', len(total_data))
# Out:
# <Response [200]>
# 1436
# total =  332224

# %%
import pandas as pd
df = pd.DataFrame(total_data)
print(df.shape)
df = df.drop_duplicates()
print(df.shape)
# Out:
# (332224, 35)
# (315210, 35)

# %%
df= pd.read_csv('housePriceData.csv')

# %%
df
# Out:
#         Unnamed: 0 AA11                a  ... unit       v year
# 0                0   其他           華齡街７０號  ...    2  0房1廳1衛  110
# 1                1   其他       延平北路六段１９１號  ...    2     NaN  110
# 2                2   其他      福國路９５號四樓之１８  ...    2  2房1廳1衛  110
# 3                3   其他  延平北路五段２８５巷９１號三樓  ...    2  1房1廳1衛  110
# 4                4   其他  社中街３４６巷１弄８之１號四樓  ...    2  2房1廳1衛  110
# ...            ...  ...              ...  ...  ...     ...  ...
# 315205      332219  工業區          中興一巷７１號  ...    2  4房2廳3衛  106
# 315206      332220  鄉村區       福德東路２９巷２１號  ...    2  5房2廳4衛  106
# 315207      332221    住       永愛路１５０巷２１號  ...    2  3房2廳1衛  106
# 315208      332222    住        中山路一段２７６號  ...    2  5房4廳3衛  106
# 315209      332223    商        漁港路１１４號二樓  ...    2  3房1廳2衛  106
#
# [315210 rows x 29 columns]

# %%
df = df.drop(columns=['AA12', 'commid', 'cp', 'es', 'fi', 
              'reid', 'note', 'mark', 'id', 'pimg', 'sq', 't'])

# %%
df.head(1000)
# Out:
#     AA11                a                b       bs  ... type  unit       v year
# 0     其他           華齡街７０號     公寓(5樓含以下無電梯)   93.43%  ...  Biz     2  0房1廳1衛  110
# 1     其他       延平北路六段１９１號     公寓(5樓含以下無電梯)  100.00%  ...  Biz     2     NaN  110
# 2     其他      福國路９５號四樓之１８    華廈(10層含以下有電梯)   96.76%  ...  Biz     2  2房1廳1衛  110
# 3     其他  延平北路五段２８５巷９１號三樓     公寓(5樓含以下無電梯)   50.36%  ...  Biz     2  1房1廳1衛  110
# 4     其他  社中街３４６巷１弄８之１號四樓    華廈(10層含以下有電梯)   37.57%  ...  Biz     2  2房1廳1衛  110
# ..   ...              ...              ...      ...  ...  ...   ...     ...  ...
# 995   其他       士商路１７９號十四樓  住宅大樓(11層含以上有電梯)   41.27%  ...  Biz     2  3房2廳1衛  110
# 996   其他    中正路２１２巷７弄３號四樓     公寓(5樓含以下無電梯)   86.77%  ...  Biz     2  3房2廳2衛  110
# 997   其他      東山路１３０巷２號五樓     公寓(5樓含以下無電梯)   83.23%  ...  Biz     2  5房2廳3衛  110
# 998   其他    中正路２１２巷６弄９號二樓     公寓(5樓含以下無電梯)   86.22%  ...  Biz     2  3房1廳1衛  110
# 999   其他  天母東路５０巷２０號四樓之１１    華廈(10層含以下有電梯)   78.58%  ...  Biz     2  2房2廳1衛  110
#
# ...

# %%
def year(timeString):
  return timeString[0:3]
df['year'] = df['e'].apply(year)
df['year']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-210-1e7529c6cfd6> in <module>()
#       1 def year(timeString):
#       2   return timeString[0:3]
# ----> 3 df['year'] = df['e'].apply(year)
#       4 df['year']
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4211             else:
#    4212                 values = self.astype(object)._values
# -> 4213                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4214
#    4215         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-210-1e7529c6cfd6> in year(timeString)
#       1 def year(timeString):
# ----> 2   return timeString[0:3]
#       3 df['year'] = df['e'].apply(year)
#       4 df['year']
#
# TypeError: 'int' object is not subscriptable

# %%
print(type(df))
# Out:
# <class 'list'>

# %%
df.to_csv('housePriceData.csv')

# %% [markdown]
# # Conbine with other data

# %% [markdown]
# ## Conbine with cement and rebar index

# %%
# install data from google drive
# !gdown --id 1XLghQCBo59g16-KJJmQth7hA96aBDkjV
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1XLghQCBo59g16-KJJmQth7hA96aBDkjV
# To: /content/costPrice.csv
# 100% 1.64k/1.64k [00:00<00:00, 3.47MB/s]

# %%
df1 = df.rename({'e': 'time'}, axis=1)

# %%
df2 = pd.read_csv('costPrice.csv')
df2.columns =['time', 'cementIndex', 'RebarIndex']
df2
# Out:
#      time  cementIndex  RebarIndex
# 0   10401       100.00      100.00
# 1   10402        96.04      100.00
# 2   10403        92.83      100.00
# 3   10404        91.97      100.00
# 4   10405        87.47      100.00
# ..    ...          ...         ...
# 78  11007       147.86      102.16
# 79  11008       146.31      102.16
# 80  11009       146.20      104.18
# 81  11010       148.08      105.51
# 82  11011       144.61      107.75
#
# [83 rows x 3 columns]

# %%
mergeDf = pd.merge(df1, df2, on='time')
mergeDf
# Out:
#        AA11                a              b  ... year cementIndex  RebarIndex
# 0        其他           華齡街７０號   公寓(5樓含以下無電梯)  ...  110      144.61      107.75
# 1        其他       延平北路六段１９１號   公寓(5樓含以下無電梯)  ...  110      144.61      107.75
# 2        其他      福國路９５號四樓之１８  華廈(10層含以下有電梯)  ...  110      144.61      107.75
# 3        其他  延平北路五段２８５巷９１號三樓   公寓(5樓含以下無電梯)  ...  110      144.61      107.75
# 4        其他  社中街３４６巷１弄８之１號四樓  華廈(10層含以下有電梯)  ...  110      144.61      107.75
# ...     ...              ...            ...  ...  ...         ...         ...
# 315204  工業區          中興一巷７１號            透天厝  ...  106       94.99       99.72
# 315205  鄉村區       福德東路２９巷２１號            透天厝  ...  106       94.99       99.72
# 315206    住       永愛路１５０巷２１號            透天厝  ...  106       94.99       99.72
# 315207    住        中山路一段２７６號            透天厝  ...  106       94.99       99.72
# 315208    商        漁港路１１４號二樓   公寓(5樓含以下無電梯)  ...  106       94.99       99.72
#
# [315209 rows x 26 columns]

# %% [markdown]
# ## Combine with interest rate

# %%
# !pip install --upgrade -q gspread

# %%
# get data from google sheets
import gspread
import pandas as pd
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gc = gspread.authorize(GoogleCredentials.get_application_default())

worksheet = gc.open_by_url('https://docs.google.com/spreadsheets/d/1Q4waDYzGDWnrqrRLEkpiLB07n3VjO5dDaczBvg2t01U/edit?usp=sharing').sheet1
rows = worksheet.get_all_values()
df3 = pd.DataFrame.from_records(rows)
new_header = df3.iloc[0] #grab the first row for the header
df3 = df3[1:] #take the data less the header row
df3.columns = new_header #set the header row as the df header
df3
# Out:
# 0    time rediscountRate loanRate  ... overnightRate commercialPaperRate bondRate
# 1   10601          1.375    1.750  ...         0.173                0.47     1.14
# 2   10602          1.375    1.750  ...         0.177                0.44     1.12
# 3   10603          1.375    1.750  ...         0.176                0.48     1.15
# 4   10604          1.375    1.750  ...         0.175                0.45     1.07
# 5   10605          1.375    1.750  ...         0.172                0.39     1.08
# 6   10606          1.375    1.750  ...         0.183                0.42     1.04
# 7   10607          1.375    1.750  ...         0.184                0.44     1.08
# 8   10608          1.375    1.750  ...         0.180                0.41     1.03
# 9   10609          1.375    1.750  ...         0.184                0.42     1.00
# 10  10610          1.375    1.750  ...         0.181                0.46     1.05
# ...

# %%
type(df3['time'].apply(str))
# Out:
# pandas.core.series.Series

# %%
mergeDf['time']=mergeDf['time'].astype(int)
df3['time']=df3['time'].astype(int)
mergeDf = pd.merge(mergeDf, df3, on='time')
mergeDf
# Out:
#        AA11               a  ... commercialPaperRate bondRate
# 0        其他    福華路１２８巷１２號二樓  ...                0.30     0.50
# 1        其他      德行東路６之２號六樓  ...                0.30     0.50
# 2        其他  至誠路一段１３６巷１７號二樓  ...                0.30     0.50
# 3        其他      文林路６６１巷１５號  ...                0.30     0.50
# 4        其他    中山北路六段４２３號五樓  ...                0.30     0.50
# ...     ...             ...  ...                 ...      ...
# 313975  工業區         中興一巷７１號  ...                0.47     1.14
# 313976  鄉村區      福德東路２９巷２１號  ...                0.47     1.14
# 313977    住      永愛路１５０巷２１號  ...                0.47     1.14
# 313978    住       中山路一段２７６號  ...                0.47     1.14
# 313979    商       漁港路１１４號二樓  ...                0.47     1.14
#
# [313980 rows x 34 columns]

# %%
mergeDf.to_csv('housePriceData.csv')

# %% [markdown]
# ## Combine with Regional Income Data

# %%
#load data from google sheets
# !gdown --id 1Ua_GHNWHVNJ1uQZDMeKqmMn1zsbC3Hai
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1LIPR_lbY5Xy0ckWVB98ZFkP05TFF_2Ul
# To: /content/housePriceData.csv
# 100% 94.3M/94.3M [00:01<00:00, 93.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Ua_GHNWHVNJ1uQZDMeKqmMn1zsbC3Hai
# To: /content/incomePerMonthPerTaiwanese.csv
# 100% 1.87k/1.87k [00:00<00:00, 4.23MB/s]

# %%
df4 = pd.read_csv('incomePerMonthPerTaiwanese.csv')
df4['time']=df4['time'].astype(int)
mergeDf = pd.merge(mergeDf, df4, on='time')
mergeDf

# %% [markdown]
# ## label column names

# %%
mergeDf[mergeDf['a'] == '承德路四段３巷２８號四樓']
# Out:
#    AA11             a  ... TWrealWage TWrealRegularWage
# 84   其他  承德路四段３巷２８號四樓  ...      47496             41375
#
# [1 rows x 38 columns]

# %%
# !gdown --id 1LIPR_lbY5Xy0ckWVB98ZFkP05TFF_2Ul
# import pandas as pd
# mergeDf = pd.read_csv('housePriceData.csv')
# mergeDf = mergeDf.drop(columns=['Unnamed: 0'])
# mergeDf

# %%
for col in mergeDf.columns:
    print(col)
# Out:
# DistrictType
# Adress
# HouseType
# BasePercent
# city
# time
# elevator
# floor
# age
# ground
# building
# park
# lat
# lon
# management
# pricePerP
# r
# area
# totalPrice
# district
# type
# unit
# v
# year
# cementIndex
# RebarIndex
# rediscountRate
# loanRate
# monthDepositRate
# yearDepositRate
# standardRate
# overnightRate
# commercialPaperRate
# bondRate
# TWtotalWagePermonth
# TWRegularPerMonth
# TWrealWage
# TWrealRegularWage

# %%
mergeDf = mergeDf.rename(columns={'AA11':'DistrictType', 'a':'Adress', 'b':'HouseType',      # /什麼區 ex:工業區/地址/房屋種類 ex:華廈
          'bs':'BasePercent', 'city':'city', 'time':'time', 'el':'elevator',    # /總面積比/././有無電梯
          'f':'floor', 'g':'age', 'j':'ground', 'k':'building', 'l':'park',   # floor:總共幾層露/位於幾樓/土地/建物/車位'
           'lat':'lat', 'lon':'lon', 'm':'management', 'p':'pricePerP', 'r':'r', # /././有無管理組織/每坪平均價格/我也不知道是什麼
           's':'area', 'tp':'totalPrice', 'twn':'district', 'type':'type', 'unit':'unit', #總坪數/總價格/行政區代號/其他我也看不懂
           'v':'v', 'year':'year'})

mergeDf
# Out:
#        DistrictType          Adress  ... TWrealWage TWrealRegularWage
# 0                其他    福華路１２８巷１２號二樓  ...      47496             41375
# 1                其他      德行東路６之２號六樓  ...      47496             41375
# 2                其他  至誠路一段１３６巷１７號二樓  ...      47496             41375
# 3                其他      文林路６６１巷１５號  ...      47496             41375
# 4                其他    中山北路六段４２３號五樓  ...      47496             41375
# ...             ...             ...  ...        ...               ...
# 313975          工業區         中興一巷７１號  ...      93671             39524
# 313976          鄉村區      福德東路２９巷２１號  ...      93671             39524
# 313977            住      永愛路１５０巷２１號  ...      93671             39524
# 313978            住       中山路一段２７６號  ...      93671             39524
# 313979            商       漁港路１１４號二樓  ...      93671             39524
#
# [313980 rows x 38 columns]

# %%
mergeDf.to_csv('housePriceData_10601to11010.csv')

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
# !cp housePriceData_10601to11010.csv "drive/My Drive/"

# %% [markdown]
# ## Combine with data without year 110

# %%
# !gdown --id 12oikSuSUdBVOLx_qX3MxGhxsj1bIo1Zh
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=12oikSuSUdBVOLx_qX3MxGhxsj1bIo1Zh
# To: /content/housePriceData_10601to11010.csv
# 100% 97.2M/97.2M [00:00<00:00, 127MB/s]

# %%
import pandas as pd
mergeDf = pd.read_csv('housePriceData_10601to11010.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (18) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# get data from google sheets
import gspread
import pandas as pd
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gc = gspread.authorize(GoogleCredentials.get_application_default())

worksheet = gc.open_by_url('https://docs.google.com/spreadsheets/d/1v3YllZIoRnlbcY-oDxu_9RXbkN-SLdv-aYLowqNeyG4/edit?usp=sharing').sheet1
rows = worksheet.get_all_values()
df5 = pd.DataFrame.from_records(rows)
new_header = df5.iloc[0] #grab the first row for the header
df5 = df5[1:] #take the data less the header row
df5.columns = new_header #set the header row as the df header
df5
df5 = df5.rename(columns={'county':'city'})

# %%
df5['year']=df5['year'].astype(int)
mergeDf['year'] = mergeDf['year'].astype(int)
mergeDf = pd.merge(mergeDf, df5, on=["year", "city"])
mergeDf = mergeDf.drop(columns=['Unnamed: 0'])
mergeDf
# Out:
#        DistrictType              Adress  ...    Save   Save Growth
# 0                其他          中社路一段９巷１４號  ...  313505   0.161559837
# 1                其他   中山北路六段１９５巷１５號五樓之２  ...  313505   0.161559837
# 2                其他   中山北路六段１９５巷１５號四樓之２  ...  313505   0.161559837
# 3                其他  延平北路八段９３巷２７號、２７號二樓  ...  313505   0.161559837
# 4                其他           菁山路７２巷１５號  ...  313505   0.161559837
# ...             ...                 ...  ...     ...           ...
# 260073          工業區             中興一巷７１號  ...  145519  -0.144287764
# 260074          鄉村區          福德東路２９巷２１號  ...  145519  -0.144287764
# 260075            住          永愛路１５０巷２１號  ...  145519  -0.144287764
# 260076            住           中山路一段２７６號  ...  145519  -0.144287764
# 260077            商           漁港路１１４號二樓  ...  145519  -0.144287764
#
# [260078 rows x 68 columns]

# %%
mergeDf.to_csv('housePriceData_10601to10912.csv')

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
# !cp housePriceData_10601to10912.csv "drive/My Drive/"
